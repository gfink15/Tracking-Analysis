# %%
from config import Categories as c
CATEGORIES = [str(cat.value[0]) for cat in c]
PERSONA_AFFINITY = {
    "gaming":           [str(c.Electronics.value[0]), str(c.Entertainment.value[0]), str(c.Gaming.value[0]), str(c.Technology.value[0]), str(c.Retail.value[0]), str(c.Software.value[0]), str(c.Crypto.value[0]), str(c.Privacy.value[0]), str(c.Stream.value[0]), str(c.Hobbies.value[0]), str(c.Events.value[0])],
    "sports_car_fan":   [str(c.Auto.value[0]), str(c.Construction.value[0]), str(c.Transport.value[0]), str(c.Hobbies.value[0])],
    "investor":         [str(c.Finance.value[0]), str(c.Business.value[0]), str(c.Career.value[0]), str(c.Charity.value[0]), str(c.Crypto.value[0]), str(c.Estate.value[0]), str(c.Insurance.value[0]), str(c.Legal.value[0])],
    "retiree":          [str(c.Entertainment.value[0]), str(c.Beauty.value[0]), str(c.Govt.value[0]), str(c.Legal.value[0]), str(c.Estate.value[0]), str(c.Travel.value[0]), str(c.Family.value[0]), str(c.Healthcare.value[0]), str(c.Events.value[0])],
    "control":  [],  # baseline — no expected affinity
    # ... fill in from your VLM category list
}
print(PERSONA_AFFINITY)
print (CATEGORIES)
# Out:
# {'gaming': ['Consumer Electronics', 'Entertainment', 'Gaming', 'Technology', 'Retail', 'Software & SaaS', 'Cryptocurrency & Web3', 'Security & Privacy', 'Streaming Services', 'Toys & Hobbies', 'Events & Conferences'], 'sports_car_fan': ['Automotive', 'Construction & Home Improvement', 'Transportation & Logistics', 'Toys & Hobbies'], 'investor': ['Finance', 'Business Services', 'Recruitment & Careers', 'Nonprofit & Charity', 'Cryptocurrency & Web3', 'Real Estate', 'Insurance', 'Legal Services'], 'retiree': ['Entertainment', 'Beauty & Personal Care', 'Government & Public Services', 'Legal Services', 'Real Estate', 'Travel & Hospitality', 'Parenting & Family', 'Healthcare', 'Events & Conferences'], 'control': []}
# ...
