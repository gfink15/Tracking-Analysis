# %%
# %load_ext autoreload
# %autoreload 2

from src.analysis.pixels import extract_pixels_from_sqlite, aggregate_pixels_by_site

hits = extract_pixels_from_sqlite(
    "data/persona_profiles/profile_crawl_2026-07-07_516d/593a6a96/crawl_data/crawl-data.sqlite",
    persona="gaming"
)
print(hits["pixel_type"].value_counts())
print(aggregate_pixels_by_site(hits).head(10))
# Out:
# pixel_type
# Google Ads Conversion    1792
# DoubleClick              1134
# Criteo                    263
# Meta Pixel                101
# TikTok Pixel               48
# Outbrain                   20
# LinkedIn Insight            6
# Taboola                     5
# Pinterest Tag               1
# Name: count, dtype: int64
#          top_level_etld1  n_pixel_hits  n_distinct_pixel_types  \
# 0    amazon-adsystem.com            16                       2
# 1        creativecdn.com             5                       2
# 2        doubleclick.net           225                       2
# 3           gamerant.com           746                       7
# 4         googleapis.com             5                       2
# 5  googlesyndication.com           193                       2
# 6         ingamenews.com             5                       2
# 7     insider-gaming.com           468                       4
# 8           pixelrtx.com            49                       2
# ...
